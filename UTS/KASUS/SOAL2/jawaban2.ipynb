# %% [markdown]
# JAWABAN STUDI KASUS NOMOR 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv('Dataset.csv')
dataset.describe
# Out:
# <bound method NDFrame.describe of           Fakultas  Jumlah_Mahasiswa Akreditasi
# 0           Bisnis               260          A
# 1    D3 Perhotelan                28          A
# 2              ICT               284          B
# 3  Ilmu Komunikasi               465          A
# 4  Seni dan Desain               735         A >

# %%
x = dataset['Fakultas']
y = dataset['Jumlah_Mahasiswa']
warna_bar = ['#F08080','#DAA520','#20B2AA','#87CEFA','#FF00FF']
plt.bar(x,y,label=x, color=warna_bar)
plt.xlabel('Nama Fakultas')
plt.ylabel('Jumlah Mahasiswa')
plt.title('Jumlah Mahasiswa Per Fakultas') 
plt.xticks(fontsize=8)
plt.legend(loc= 'center right',bbox_to_anchor=(1.4,0.5))
plt.show()
