# %%
from sklearn.utils import shuffle
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

dataset = pd.read_csv('k-nn/Dataset.csv')
data = dataset.iloc[:,1:]

# %% [markdown]
# Encoding Categorical data into Numerical Data

# %%
le = preprocessing.LabelEncoder()
buying = le.fit_transform(list(dataset["buying"]))
maint = le.fit_transform(list(dataset["maint"]))
door = le.fit_transform(list(dataset["door"]))
persons = le.fit_transform(list(dataset["persons"]))
lug_boot = le.fit_transform(list(dataset["lug_boot"]))
safety = le.fit_transform(list(dataset["safety"]))
cls = le.fit_transform(list(dataset["class"]))
print(buying)
print(maint)
print(door)
print(persons)
print(lug_boot)
print(safety)
print(cls)
# Out:
# [3 3 3 ... 1 1 1]
# [3 3 3 ... 1 1 1]
# [0 0 0 ... 3 3 3]
# [0 0 0 ... 2 2 2]
# [2 2 2 ... 0 0 0]
# [1 2 0 ... 1 2 0]
# [2 2 2 ... 2 1 3]

# %% [markdown]
# Splitting Dataset

# %%
from sklearn.model_selection import train_test_split

predict = "class"
x = list(zip(buying, maint, door, persons, lug_boot, safety)) # features
y = list(cls) # labels
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1)

# %% [markdown]
# Training Model with K-NN

# %%
from sklearn.neighbors import KNeighborsClassifier


neighbors = 9 ### jumlah tetangga terdekat yang dilibatkan untuk prediksi
model = KNeighborsClassifier(n_neighbors=neighbors)
model.fit(x_train, y_train)

acc = model.score(x_test, y_test) ### akurasi model
print(acc)
# Out:
# 0.9479768786127167

# %%
predicted = model.predict(x_test)
label = ["unacc", "acc", "good", "vgood"]

# print(predicted)
for x in range(len(predicted)):
    print("Predicted: ", label[predicted[x]])
    print("Data: ", x_test[x])
    print("Actual: ", label[y_test[x]])
    
    n = model.kneighbors([x_test[x]], neighbors, True)
    print("N: ", n)
    print()
    print()
# Out:
# Predicted:  good
# Data:  (0, 3, 0, 0, 1, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 788, 1004,  232, 1500, 1015,  998, 1266,  368,  444]]))
#
#
# Predicted:  good
# Data:  (2, 0, 2, 0, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 141, 1527,  400,  778,  244,  464,  427,  316,  218]]))
#
#
# Predicted:  good
# Data:  (3, 0, 0, 2, 1, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1145,  940, 1002, 1301, 1511,  360, 1117,  694, 1276]]))
#
#
# Predicted:  good
# Data:  (0, 1, 0, 0, 1, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1422, 1177,  750, 1303,  769, 1309,  648,  874,  983]]))
#
#
# Predicted:  good
# Data:  (0, 1, 2, 0, 0, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 162, 1008, 1166,  482, 1273, 1443,  640,  175,  111]]))
#
#
# Predicted:  good
# Data:  (3, 2, 1, 2, 2, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 599,  454, 1144,   53,  938,  991,   64,  215, 1272]]))
#
#
# Predicted:  good
# Data:  (2, 1, 0, 0, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 485, 1526,  583, 1312,  407,  562, 1541, 1129, 1491]]))
#
#
# Predicted:  unacc
# Data:  (2, 2, 3, 1, 0, 2)
# Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 382,  685, 1310,  326,  671,  759,  970, 1133, 1224]]))
#
#
# Predicted:  good
# Data:  (0, 3, 2, 1, 0, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 216, 1440,  554,  176,  656,  423, 1399, 1455,  553]]))
#
#
# Predicted:  good
# Data:  (2, 3, 1, 1, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 142, 1051, 1487, 1100,  358,  315,   41,  436, 1501]]))
#
#
# Predicted:  good
# Data:  (0, 1, 0, 2, 2, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1529, 1360, 1522,  332,    3,  549,  691,  335,  966]]))
#
#
# Predicted:  good
# Data:  (0, 1, 2, 0, 0, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 737,  497, 1315, 1308,  628, 1062, 1314,  175,  640]]))
#
#
# Predicted:  vgood
# Data:  (1, 2, 2, 1, 1, 0)
# Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 695,  437, 1469, 1097, 1083,  266,   59,  178,  493]]))
#
#
# Predicted:  good
# Data:  (3, 2, 0, 1, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1549, 1259, 1364,  889,  297,  409, 1294,  617,   28]]))
#
#
# Predicted:  good
# Data:  (2, 1, 0, 2, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  96,  865,  974, 1439,  132,  801, 1464,  460,  696]]))
#
#
# Predicted:  good
# Data:  (0, 1, 1, 1, 2, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 366,  431,  549, 1304,  332,  602, 1508, 1291,  746]]))
#
#
# Predicted:  unacc
# Data:  (2, 0, 3, 1, 1, 0)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 229, 1231,  214,  576,  703,  406,  820,  367, 1052]]))
#
#
# Predicted:  good
# Data:  (0, 1, 3, 0, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 852,  456,  591, 1037, 1398,  308,  772,  781,  745]]))
#
#
# Predicted:  good
# Data:  (2, 0, 1, 0, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1046,  593,  605,  137,  279,  338,  171,  976,   71]]))
#
#
# Predicted:  good
# Data:  (0, 2, 1, 1, 1, 2)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 622, 1490,  444, 1446,   87,  368,   29,  127,   49]]))
#
#
# Predicted:  good
# Data:  (0, 3, 1, 1, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 369,  875, 1449, 1338,  789,  127,  911,   87,  106]]))
#
#
# Predicted:  unacc
# Data:  (3, 1, 3, 1, 0, 0)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1270,  160,  947, 1169,   17,  181,  196,  951,  567]]))
#
#
# Predicted:  good
# Data:  (2, 2, 2, 0, 0, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 964,  399,  223, 1411,  652, 1095, 1463, 1469,  493]]))
#
#
# Predicted:  good
# Data:  (2, 0, 1, 0, 0, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 338, 1101,  425,  523, 1465,  539, 1279,  356,  882]]))
#
#
# Predicted:  good
# Data:  (3, 2, 1, 2, 1, 2)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1125,  938,  613,  617,  599,   55,  961,  341,  409]]))
#
#
# Predicted:  good
# Data:  (3, 1, 2, 0, 1, 2)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  95,  107, 1397, 1473,  556,  233, 1039,  465, 1243]]))
#
#
# Predicted:  unacc
# Data:  (0, 1, 3, 2, 0, 0)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1426, 1196,  304,  519,  679,  258, 1157, 1059,  864]]))
#
#
# Predicted:  unacc
# Data:  (0, 0, 3, 2, 1, 0)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 888, 1196,  849, 1200,  434,  188, 1157, 1059,  321]]))
#
#
# Predicted:  good
# Data:  (1, 2, 2, 0, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1066, 1280,   30,  682,  169,  373,  418,  102,  451]]))
#
#
# Predicted:  good
# Data:  (1, 3, 0, 2, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 644,  339,   10,  608,  534,  834,  424,  775, 1415]]))
#
#
# Predicted:  good
# Data:  (3, 3, 2, 0, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 394, 1477, 1497, 1496,  547,  629,  124,  259, 1193]]))
#
#
# Predicted:  good
# Data:  (3, 0, 0, 0, 2, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 361,  112, 1344, 1102,  334,  813,  833, 1046,  976]]))
#
#
# Predicted:  good
# Data:  (1, 1, 3, 2, 2, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1239,  621,  503, 1543, 1229,  253,  796,  411,   18]]))
#
#
# Predicted:  good
# Data:  (0, 3, 2, 2, 0, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 163, 1226, 1197,  606, 1551,   97,  268, 1387, 1187]]))
#
#
# Predicted:  good
# Data:  (2, 3, 3, 1, 2, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 987, 1089, 1262, 1174, 1531, 1379,  917, 1329, 1552]]))
#
#
# Predicted:  good
# Data:  (3, 2, 1, 1, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 617, 1085,  898, 1151,  484,  521, 1236,  599, 1144]]))
#
#
# Predicted:  good
# Data:  (3, 2, 0, 1, 0, 2)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1549,   26,  777,  235,  139,  140,  409,  617,  726]]))
#
#
# Predicted:  vgood
# Data:  (1, 2, 3, 2, 1, 0)
# Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 841, 1330, 1244,  320, 1389,  695,  977,   59,  697]]))
#
#
# Predicted:  unacc
# Data:  (1, 2, 1, 1, 1, 2)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 212,   57,  421, 1352, 1147,  710, 1022,  526,   29]]))
#
#
# Predicted:  good
# Data:  (2, 2, 2, 0, 1, 0)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 493,   31,  168,  578,   92,  260, 1195,  654,  195]]))
#
#
# Predicted:  good
# Data:  (1, 0, 1, 0, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 425,  744,  441, 1101, 1289, 1295, 1358,  655,  198]]))
#
#
# Predicted:  unacc
# Data:  (1, 2, 0, 1, 1, 0)
# Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 166,  428,  886, 1104,  524,  325, 1248, 1088, 1181]]))
#
#
# Predicted:  good
# Data:  (1, 1, 0, 0, 1, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1285,  981, 1365,  918, 1417,  220,  760,  159, 1309]]))
#
#
# Predicted:  good
# Data:  (0, 2, 3, 2, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 792, 1339, 1435,  968, 1020,  623, 1517, 1018, 1175]]))
#
#
# Predicted:  unacc
# Data:  (0, 1, 1, 1, 0, 2)
# Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  29, 1314,  854, 1505,  412,  622,  628,  433, 1311]]))
#
#
# Predicted:  good
# Data:  (3, 2, 2, 2, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 276,  529, 1299,  649,  675,  445, 1453,  662, 1065]]))
#
#
# Predicted:  good
# Data:  (3, 2, 0, 2, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1272,  865,  801, 1507,  980,  599,  708,  529,  409]]))
#
#
# Predicted:  good
# Data:  (2, 3, 2, 0, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 380,  329, 1195, 1120,   92, 1029,  259,  290,    8]]))
#
#
# Predicted:  good
# Data:  (2, 3, 2, 0, 0, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1247,  393,  165,  764,  553, 1029, 1195,  432, 1463]]))
#
#
# Predicted:  good
# Data:  (2, 2, 1, 1, 2, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 991, 1456, 1236, 1349, 1144,  541, 1392,  921,  692]]))
#
#
# Predicted:  good
# Data:  (0, 1, 3, 1, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 563, 1539,  837,  242,  461,  701,  545,  351, 1532]]))
#
#
# Predicted:  good
# Data:  (0, 0, 3, 0, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 308,  745,  781,  941,  852,  872, 1037,   51,  591]]))
#
#
# Predicted:  good
# Data:  (1, 1, 1, 1, 2, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1515, 1456, 1287,  818, 1227, 1170, 1405,  430, 1023]]))
#
#
# Predicted:  unacc
# Data:  (2, 2, 1, 1, 1, 2)
# Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 784,  774, 1236,  420,  961,  617,  303,  541, 1290]]))
#
#
# Predicted:  good
# Data:  (0, 1, 1, 2, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 935, 1118, 1360,  602, 1081, 1350,  549,  560, 1219]]))
#
#
# Predicted:  good
# Data:  (0, 3, 2, 1, 1, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1184,  747, 1226,  369, 1399, 1097,  651, 1083, 1440]]))
#
#
# Predicted:  good
# Data:  (0, 3, 1, 0, 0, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1525, 1202,  998, 1366,  635,  150, 1077,  548, 1333]]))
#
#
# Predicted:  good
# Data:  (2, 0, 1, 2, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  86, 1394,  477, 1553, 1441, 1380,  287,   54,   15]]))
#
#
# Predicted:  good
# Data:  (0, 3, 0, 1, 1, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 734,  895, 1248, 1338,  510,  646,  325,  369,   48]]))
#
#
# Predicted:  unacc
# Data:  (1, 2, 3, 2, 1, 2)
# Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 811,  392,  167,  466,  697, 1339,  623,  395,  514]]))
#
#
# Predicted:  good
# Data:  (1, 1, 3, 0, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 799,  941, 1341,  169,  505,  591,  852,   51,  536]]))
#
#
# Predicted:  good
# Data:  (3, 3, 1, 0, 1, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[   6,  839,  547,  124,  252,  739, 1055,  867,  484]]))
#
#
# Predicted:  good
# Data:  (0, 2, 2, 0, 1, 0)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 728, 1306, 1083,  111, 1221,  417, 1399, 1324,  493]]))
#
#
# Predicted:  unacc
# Data:  (2, 3, 1, 2, 1, 0)
# Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 948,   66,  814, 1003,  825,  292, 1121,  730, 1268]]))
#
#
# Predicted:  unacc
# Data:  (1, 0, 2, 1, 1, 2)
# Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 190, 1383,  422,  615,  204,  581,  844,   94, 1040]]))
#
#
# Predicted:  good
# Data:  (0, 0, 3, 0, 1, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 254, 1384,  390,  888,  134,  275,  665,  111,   14]]))
#
#
# Predicted:  good
# Data:  (1, 1, 3, 0, 2, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 591,   51,  451,  447,  702, 1134,  411,  563, 1519]]))
#
#
# Predicted:  good
# Data:  (0, 0, 1, 0, 0, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 147,  885,  198,  665, 1372,  655,  116,  750,  174]]))
#
#
# Predicted:  good
# Data:  (1, 2, 0, 1, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 166,  886, 1513, 1479,  473, 1154, 1316,  458,  919]]))
#
#
# Predicted:  good
# Data:  (3, 1, 2, 1, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 233, 1260, 1473, 1230,  239, 1414,  798,  633,   11]]))
#
#
# Predicted:  good
# Data:  (0, 0, 2, 1, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 347,  520,  569, 1086,  199, 1320, 1443,  640,  280]]))
#
#
# Predicted:  good
# Data:  (2, 3, 2, 0, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[  27,  329,  763,  731,   30,  290,  248, 1066, 1346]]))
#
#
# Predicted:  good
# Data:  (2, 3, 3, 2, 2, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 878,  704,  221, 1176, 1014,  413, 1379,  987,   18]]))
#
#
# Predicted:  good
# Data:  (3, 0, 1, 2, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 477, 1256,  830,  149,  360,  819, 1145,   86,  995]]))
#
#
# Predicted:  good
# Data:  (1, 2, 1, 2, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 657,  589, 1154,  807,  666,  473,   69,  457, 1381]]))
#
#
# Predicted:  good
# Data:  (0, 0, 3, 1, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[222, 328, 456, 536, 771, 391, 206, 745, 781]]))
#
#
# Predicted:  good
# Data:  (0, 2, 2, 0, 1, 2)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 728,  444,  879,  497, 1280, 1490, 1036, 1315,  102]]))
#
#
# Predicted:  good
# Data:  (1, 1, 1, 0, 0, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1505, 1358, 1077, 1308,  425, 1365,  628, 1465,  213]]))
#
#
# Predicted:  unacc
# Data:  (1, 1, 0, 2, 1, 0)
# Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 582,  931,  388,  460, 1088, 1073,  966,   74,  401]]))
#
#
# Predicted:  good
# Data:  (0, 1, 1, 0, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  67, 1544,  482,  602, 1177,  746,  863,  174, 1309]]))
#
#
# Predicted:  good
# Data:  (3, 1, 3, 0, 2, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 357,  158,  876,  795,  702,  344, 1115,  233,  465]]))
#
#
# Predicted:  unacc
# Data:  (0, 1, 0, 1, 0, 0)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 690, 1422, 1303, 1127, 1470,  402,   40,  790,  881]]))
#
#
# Predicted:  good
# Data:  (3, 1, 0, 0, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1491, 1294,  897, 1364, 1344, 1404,  112,  463,  485]]))
#
#
# Predicted:  unacc
# Data:  (3, 2, 0, 1, 0, 0)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 861,  708, 1388,  601, 1549, 1530,  297,  438,  544]]))
#
#
# Predicted:  unacc
# Data:  (1, 0, 0, 1, 1, 2)
# Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 403,  122,  660,  159,  331,  405,  532,  760, 1383]]))
#
#
# Predicted:  vgood
# Data:  (2, 1, 2, 1, 0, 0)
# Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 181,  479,  964, 1430, 1069,  353,  399,  240, 1169]]))
#
#
# Predicted:  good
# Data:  (2, 1, 3, 0, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 246, 1554, 1408, 1257,  567,  234, 1376, 1049,  871]]))
#
#
# Predicted:  good
# Data:  (2, 1, 3, 0, 2, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 344,  702,  535, 1148,  103,  114, 1281,  840,  926]]))
#
#
# Predicted:  good
# Data:  (1, 2, 0, 0, 0, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 983,  902,  166,  144,  524, 1442,  618,  458,  566]]))
#
#
# Predicted:  good
# Data:  (2, 2, 0, 1, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 784, 1464, 1236,   38,  865,  428,  692,  528, 1368]]))
#
#
# Predicted:  good
# Data:  (0, 3, 1, 0, 1, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 877,  789,  444,  879, 1375,  127,  150, 1202,  635]]))
#
#
# Predicted:  good
# Data:  (0, 3, 3, 0, 1, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1221,  131,  802,  747, 1399,  736, 1440,  295, 1355]]))
#
#
# Predicted:  good
# Data:  (3, 1, 1, 0, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 107,  593, 1230,  233,  171, 1498,  486,  256,   71]]))
#
#
# Predicted:  good
# Data:  (2, 0, 0, 2, 2, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 324, 1213,  100,   60,  709,  570,   16,  899,  257]]))
#
#
# Predicted:  unacc
# Data:  (1, 3, 3, 1, 2, 0)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1098, 1293,  231, 1262,  538, 1035,    1, 1379,  281]]))
#
#
# Predicted:  good
# Data:  (3, 3, 2, 1, 0, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 475, 1351,  393, 1247,  687,  749, 1051,  124,  629]]))
#
#
# Predicted:  good
# Data:  (1, 2, 2, 2, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1325,  210,  178, 1353, 1514, 1499,   59,  697,  811]]))
#
#
# Predicted:  unacc
# Data:  (2, 1, 1, 2, 1, 2)
# Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1125, 1094,  767,  961, 1452, 1369,  420,  132,  696]]))
#
#
# Predicted:  good
# Data:  (2, 3, 0, 0, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 579,  824,  731,  880, 1253,    2,  729, 1546,  379]]))
#
#
# Predicted:  good
# Data:  (3, 0, 4, 1, 1, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 365,  516,  442, 1005,  160,  311,  975, 1264,  129]]))
#
#
# Predicted:  good
# Data:  (2, 1, 2, 1, 2, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[  90,  873,  681, 1114,  633,  688,  985,  942,  786]]))
#
#
# Predicted:  good
# Data:  (1, 2, 0, 2, 1, 0)
# Actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1178,  891,  429,   88,  725,  855, 1067,  966,  473]]))
#
#
# Predicted:  good
# Data:  (3, 2, 2, 0, 2, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 564,  962,  414,  804,  654,  416,  168, 1180, 1400]]))
#
#
# Predicted:  unacc
# Data:  (1, 0, 0, 2, 0, 0)
# Actual:  vgood
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[716, 881, 270, 582, 931, 916,  83, 790, 193]]))
#
#
# Predicted:  unacc
# Data:  (0, 0, 1, 2, 1, 2)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1219,  560,  937,  192,  363,  518,  492,  979, 1383]]))
#
#
# Predicted:  good
# Data:  (0, 2, 2, 1, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 632, 1373,  733, 1443,  822,   47,  554, 1166, 1427]]))
#
#
# Predicted:  good
# Data:  (3, 3, 3, 0, 2, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 564,  856, 1180,  972, 1193, 1497,  124, 1089,    4]]))
#
#
# Predicted:  good
# Data:  (1, 1, 2, 0, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1406,  447,  852, 1116, 1436,  508,  283,  581,  497]]))
#
#
# Predicted:  good
# Data:  (2, 3, 3, 0, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1161, 1089, 1497,  603, 1524, 1223,  699, 1329,  754]]))
#
#
# Predicted:  unacc
# Data:  (2, 1, 2, 1, 2, 2)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1116,  322,  908,  318,  667,  302, 1406,  381,  505]]))
#
#
# Predicted:  good
# Data:  (1, 1, 1, 0, 1, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 212, 1436,  661,  283,  213, 1022,  863,   67, 1383]]))
#
#
# Predicted:  acc
# Data:  (1, 2, 1, 1, 2, 0)
# Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1227, 1392, 1104,  818, 1181, 1409,   82, 1019,  958]]))
#
#
# Predicted:  good
# Data:  (2, 3, 3, 2, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1245,  277, 1431,  803,  467,  624,  471,  498,  221]]))
#
#
# Predicted:  good
# Data:  (0, 2, 1, 0, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 573, 1166, 1275, 1373, 1202,  994,  482,  150, 1544]]))
#
#
# Predicted:  unacc
# Data:  (3, 2, 2, 1, 1, 2)
# Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 741,  587,  613, 1473,  774, 1414,  349, 1039,   19]]))
#
#
# Predicted:  good
# Data:  (3, 3, 3, 1, 0, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 687,  489,  748, 1402,  345,   42,  626, 1161,  698]]))
#
#
# Predicted:  good
# Data:  (3, 1, 2, 0, 2, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 233,  633, 1115,  486,  962,  681,  414,  465,  244]]))
#
#
# Predicted:  good
# Data:  (3, 2, 0, 2, 1, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 846,  409, 1511, 1478, 1056,  617,  284,  599,  341]]))
#
#
# Predicted:  unacc
# Data:  (0, 2, 2, 1, 0, 0)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1469,  455,  776,  163,  869, 1324, 1083,  223,   47]]))
#
#
# Predicted:  good
# Data:  (3, 1, 1, 0, 0, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 480,  354,  828, 1397, 1465,  107, 1216,  356, 1129]]))
#
#
# Predicted:  good
# Data:  (3, 0, 4, 1, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 707,  186,  311, 1207, 1264,   77,  659,  580, 1326]]))
#
#
# Predicted:  vgood
# Data:  (2, 1, 2, 1, 1, 0)
# Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 578, 1433,  963,  195,  820,  985,  367,   90,  437]]))
#
#
# Predicted:  good
# Data:  (0, 2, 0, 1, 2, 0)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 646,   82, 1248,  986, 1104,  597, 1390, 1548,    3]]))
#
#
# Predicted:  good
# Data:  (0, 3, 3, 0, 0, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 592, 1440, 1428, 1026,  656, 1399,  802,  736, 1455]]))
#
#
# Predicted:  good
# Data:  (3, 3, 1, 1, 0, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 252,  739,  862,  315, 1501, 1388,  601, 1079,  764]]))
#
#
# Predicted:  unacc
# Data:  (2, 2, 1, 1, 0, 2)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 909,   26,  710,  671,   68, 1487, 1267,  777,  341]]))
#
#
# Predicted:  acc
# Data:  (1, 2, 2, 1, 1, 2)
# Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 167,  204,  811,   79,  373, 1490,  178,   61,  102]]))
#
#
# Predicted:  unacc
# Data:  (1, 3, 3, 2, 0, 0)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1551,  928, 1244,  841,  982,  992, 1197, 1098,  624]]))
#
#
# Predicted:  unacc
# Data:  (3, 2, 0, 2, 0, 2)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[  89,  341,  694, 1507, 1105, 1056,  529,   26,  409]]))
#
#
# Predicted:  good
# Data:  (1, 0, 2, 0, 1, 0)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1052, 1271, 1485,  427, 1034,  254,  275,  316,  637]]))
#
#
# Predicted:  good
# Data:  (1, 3, 3, 0, 0, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 936, 1223,  816, 1161,  173,  592, 1026,  432,  736]]))
#
#
# Predicted:  good
# Data:  (0, 1, 3, 0, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1134, 1037,  175,  590,  134,  591, 1273,  737,  111]]))
#
#
# Predicted:  unacc
# Data:  (1, 3, 2, 2, 1, 2)
# Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 954,  101,   79,  693,  959,  514,  811, 1353,  182]]))
#
#
# Predicted:  good
# Data:  (1, 3, 2, 1, 2, 2)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1066,  645, 1063,  763,   79,  281,  373,  184,  954]]))
#
#
# Predicted:  acc
# Data:  (1, 1, 2, 2, 0, 2)
# Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 172, 1021, 1332, 1031, 1041, 1357, 1348,   44,  293]]))
#
#
# Predicted:  good
# Data:  (2, 2, 1, 1, 0, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[  58,  589, 1236, 1139, 1154,  898,  528, 1545,   68]]))
#
#
# Predicted:  good
# Data:  (0, 1, 0, 0, 2, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1390,  490,  874,  597, 1437, 1064,  230,  117,   72]]))
#
#
# Predicted:  unacc
# Data:  (0, 1, 3, 1, 2, 0)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1393,  563,  926,  860,  156,  701,   32,  978,  134]]))
#
#
# Predicted:  good
# Data:  (0, 0, 0, 0, 0, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 768,  198, 1295, 1313,  885, 1043,  800,  750, 1099]]))
#
#
# Predicted:  good
# Data:  (3, 0, 0, 1, 2, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[  35,  721, 1102,  324,  334,   60,  843,  191,  377]]))
#
#
# Predicted:  good
# Data:  (2, 1, 1, 2, 2, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 509, 1405, 1439,  991,  767,  257,  696,   53, 1456]]))
#
#
# Predicted:  unacc
# Data:  (0, 0, 1, 2, 0, 2)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 109,  979, 1208, 1311,  609,  433, 1371,  937,  520]]))
#
#
# Predicted:  good
# Data:  (1, 1, 3, 0, 2, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1137,  840,  926,  643, 1033,  978, 1384,   24,  134]]))
#
#
# Predicted:  good
# Data:  (0, 0, 1, 2, 2, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 560,  472, 1529, 1053,  363,  625, 1291,  549, 1023]]))
#
#
# Predicted:  good
# Data:  (2, 3, 3, 1, 0, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1051, 1161,  759, 1431,  816,  626,  326,  699,  498]]))
#
#
# Predicted:  good
# Data:  (3, 3, 2, 1, 0, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 445, 1051,  698,  315, 1299,  629, 1029,  829,  393]]))
#
#
# Predicted:  good
# Data:  (0, 0, 0, 0, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 558,  750, 1309,  459,  800,  174,  161, 1064,  198]]))
#
#
# Predicted:  good
# Data:  (1, 2, 0, 0, 2, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1516,  620,  481, 1401,   63,  610,  453,  588,  474]]))
#
#
# Predicted:  good
# Data:  (2, 3, 3, 1, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 259,  498,  237, 1402,  559,  699, 1379, 1283,  624]]))
#
#
# Predicted:  good
# Data:  (1, 0, 0, 0, 1, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 401,  800,  648,  857,  750, 1271, 1099,  117, 1064]]))
#
#
# Predicted:  good
# Data:  (0, 3, 2, 2, 0, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 959,  201,  920,  668,  182,   97,  268, 1457, 1194]]))
#
#
# Predicted:  good
# Data:  (3, 3, 0, 1, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1212,  574, 1475, 1162, 1135,  729,  880,  379,  846]]))
#
#
# Predicted:  vgood
# Data:  (1, 0, 1, 2, 0, 0)
# Actual:  vgood
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 289, 1143, 1441,  301,  927,   83,   15,  931,  808]]))
#
#
# Predicted:  good
# Data:  (2, 1, 3, 2, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 796,  949, 1321,  944, 1319,  621,  348, 1328,  717]]))
#
#
# Predicted:  good
# Data:  (3, 2, 2, 1, 2, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1377,  633,  454,  924, 1414,  962,  741,  873,  416]]))
#
#
# Predicted:  good
# Data:  (3, 3, 3, 0, 2, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1089, 1497,  357, 1496,  917,   27,  564,  248,  249]]))
#
#
# Predicted:  good
# Data:  (2, 3, 3, 0, 1, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 856, 1193,  699,  260,  802,  165, 1195,    8,  806]]))
#
#
# Predicted:  good
# Data:  (2, 1, 1, 1, 0, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 909, 1553, 1374,  922,  287, 1250, 1129,  407,  479]]))
#
#
# Predicted:  good
# Data:  (3, 3, 3, 2, 0, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1431, 1299, 1245,  662, 1504, 1030,  475,  499,  988]]))
#
#
# Predicted:  good
# Data:  (3, 3, 3, 0, 2, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1189,   27,  249,  248,  870,  145,  375, 1089,  394]]))
#
#
# Predicted:  unacc
# Data:  (0, 2, 2, 2, 0, 2)
# Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1427,  205,   44, 1348,  203,  822, 1432,  811, 1339]]))
#
#
# Predicted:  good
# Data:  (3, 1, 0, 2, 2, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1363,  641,  570,   35,  105,  324, 1382,  899,   53]]))
#
#
# Predicted:  good
# Data:  (2, 1, 0, 1, 2, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 377,  692, 1439, 1057, 1464, 1456, 1204,  191,  513]]))
#
#
# Predicted:  good
# Data:  (3, 3, 0, 2, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 272,  307, 1478,  900,  889,  705, 1087, 1460, 1272]]))
#
#
# Predicted:  good
# Data:  (2, 2, 0, 0, 1, 2)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1290, 1417, 1368,  918, 1192, 1492,  824,  784,    2]]))
#
#
# Predicted:  unacc
# Data:  (0, 2, 1, 2, 1, 0)
# Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 855, 1093, 1118,  450, 1067, 1350,  211,  342, 1130]]))
#
#
# Predicted:  good
# Data:  (3, 3, 2, 1, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 587, 1351, 1323, 1151,  259, 1402,  924,  741,  698]]))
#
#
# Predicted:  good
# Data:  (1, 0, 2, 1, 1, 1)
# Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 316,  778, 1052, 1240, 1086,  925, 1211,  280,  999]]))
#
#
# Predicted:  good
# Data:  (3, 3, 1, 1, 1, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 617,  574, 1151,  587,   55, 1162,  303,   39, 1126]]))
#
#
# Predicted:  unacc
# Data:  (1, 3, 1, 1, 0, 2)
# Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 710,  892, 1352, 1487, 1100,  584,  635, 1366,  288]]))
#
#
# Predicted:  good
# Data:  (3, 3, 1, 1, 0, 2)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1487,  235,  677,  780,  698,   26,  315,  828,  715]]))
#
#
# Predicted:  good
# Data:  (0, 0, 3, 0, 1, 1)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1140,  745, 1458,  461,  884,  308,  390,  175,  134]]))
#
#
# Predicted:  good
# Data:  (3, 0, 2, 2, 2, 0)
# Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 298,  245,  732,  899,  494, 1336,  607,   91,    9]]))
